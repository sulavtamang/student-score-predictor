# %%
# %reset -f

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
student_score_df = pd.read_csv('../datasets/study_hours_scores.csv')

# %%
student_score_df
# Out:
#       Study Hours     Scores
# 0        8.988963  32.970980
# 1       22.817143  79.317052
# 2       17.567855  68.210315
# 3       14.367804  62.038583
# 4        3.744447  17.665939
# ...           ...        ...
# 4995    21.537536  97.354775
# 4996     2.865144  13.842728
# 4997     7.868228  30.706610
# 4998    19.577889  85.387579
# 4999    14.335497  66.551066
#
# [5000 rows x 2 columns]

# %%
rmse = np.sqrt(mean_squared_error(y, y_pred))
print(f"RMSE: {rmse}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 rmse = np.sqrt(mean_squared_error(y, y_pred))
#       2 print(f"RMSE: {rmse}")
#
# NameError: name 'y' is not defined

# %%
plt.figure(figsize=(20, 10))
plt.scatter(student_score_df['Study Hours'], student_score_df['Scores'])
plt.tight_layout()
plt.show()
