# %%
# %reset -f

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

student_scores = pd.read_csv('../datasets/study_hours_scores.csv')
student_scores
# Out:
#       Study Hours  Scores
# 0            8.99   32.98
# 1           22.82   79.33
# 2           17.57   68.22
# 3           14.37   62.05
# 4            3.74   17.65
# ...           ...     ...
# 4995        21.54   97.36
# 4996         2.87   13.86
# 4997         7.87   30.71
# 4998        19.58   85.40
# 4999        14.34   66.57
#
# [5000 rows x 2 columns]

# %%
# Split data into features and target
x = student_scores[['Study Hours']]  # Features
y = student_scores['Scores']  # Target

# Scaling the data using StandardScaler
# scaler = StandardScaler()
# data[['Study Hours', 'Scores']] = scaler.fit_transform(data[['Study Hours', 'Scores']])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# Train a linear regression model
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)

# Predict the scores
y_pred = linear_model.predict(x_test)

# Calculate MSE and RMSE
mse = mean_squared_error(x_test, y_pred)
print(f'MSE: {mse:.2f}')

rmse = np.sqrt(mse)
print(f"RMSE: {rmse}")
# Out:
# MSE: 1696.59
# RMSE: 41.18971044451608

# %%
# Visualize the relationship
plt.scatter(student_scores['Study Hours'], student_scores['Scores'], alpha=0.5, color='b', edgecolors='k')
plt.plot(x_test, y_pred, color='red', linewidth=2)

plt.title("Study Hours vs Scores with Linear Regression Fit")
plt.xlabel("Study Hours (Scaled)")
plt.ylabel("Scores (Scaled)")
plt.show()

# %%
linear_model.predict([[24]])
# Out:
# D:\Data Science\Data Science Projects\student_score_prediction_system\env\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([95.49584226])
